# %% [markdown]
# # MUHAMMAD NABEL FATHAHILLAH 202332125

# %%
pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\mnabe\anaconda3\lib\site-packages (1.26.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\mnabe\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\mnabe\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: seaborn in c:\users\mnabe\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mnabe\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mnabe\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mnabe\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mnabe\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mnabe\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mnabe\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mnabe\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mnabe\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\mnabe\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mnabe\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\mnabe\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Membuat Bar Chart

# %%
matakuliah = ['Dasar Pemrograman','Basis Data','Machine Learning','Pemrograman Objek','Pemrograman Web']
jumlah_mahasiswa = [125,90,120,99,77]

plt.figure(figsize=(22,7))
plt.barh(matakuliah, jumlah_mahasiswa, color = 'blue')
plt.title('Jumlah Mahasiswa pada Mata Kuliah di Semester 3', size = 14)
plt.xlabel('Jumlah Mahasiswa, size = 12')
plt.xticks(size=14)
plt.yticks(size=14)
plt.show()

# %%
#line chart
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
Nilai = [80, 90, 65, 75, 79, 82]
ax.plot(Nilai)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([10,0,1,1])
ax.axis('equal')
stock = ['cheese', 'bread', 'milk', 'ice cream', 'noodles', 'egg']
sold = [10,50,45,15,37,115]
ax.pie (sold, labels = stock, autopct = '%1.2f%%')
plt.gca().set_aspect('equal', adjustable='box')

plt.show()

# %%
#Data untuk tiga kategori
akomodasi = [2000, 1100, 4180, 5800, 6420, 980]
kamar = [1503, 10732, 3555, 5206, 2187, 4731, 522]
kasur = [9257, 16415, 6045, 7832, 2885, 8080, 786]
 
# Membuat figure dan axis
fig, ax = plt.subplots(figsize=(8,6))  # Ukuran lebih jelas
 
# Membuat boxplot dengan berbagai pengaturan
box = ax.boxplot([akomodasi, kamar, kasur],
                 vert=False,  # Membuat boxplot horizontal
                 showmeans=True,  # Menampilkan nilai mean
                 meanline=True,  # Menampilkan mean sebagai garis
                 tick_labels=['Akomodasi', 'Kamar', 'Kasur'],  # Perbaikan: 'labels' → 'tick_labels'
                 patch_artist=True,  # Memberikan warna pada boxplot
                 medianprops={'linewidth': 2, 'color': 'blue'},  # Warna garis median
                 meanprops={'linewidth': 2, 'color': 'red'})  # Warna garis mean
 
# Menambahkan warna untuk setiap box
colors = ['lightblue', 'lightgreen', 'lightcoral']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)
 
# Menyesuaikan aspek agar tidak terjadi peringatan
ax.set_aspect('auto')
 
# Menampilkan plot
plt.show()

# %%
## Scatter Plot
 
# Data nilai tugas, UTS, dan UAS
tugas = [58, 80, 65, 79, 82]
uts = [78, 80, 85, 59, 92]
uas = [62, 79, 87, 77, 84]
 
# Membuat figure dan axis
fig, ax = plt.subplots()
 
# Scatter plot hubungan tugas dengan UTS
ax.scatter(tugas, uts, color='red', label='Tugas vs UTS')
# Scatter plot hubungan tugas dengan UAS
ax.scatter(tugas, uas, color='blue', label='Tugas vs UAS')
 
# Menambahkan label sumbu dan judul
tempX = 'Tugas'
tempY = 'Nilai'
ax.set_xlabel(tempX)
ax.set_ylabel(tempY)
ax.set_title('Scatter Plot')
 
# Menampilkan legenda
ax.legend()
 
# Menampilkan plot
plt.show()
